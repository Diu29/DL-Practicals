# %%
pip install tensorflow
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# Collecting tensorflow
#   Using cached tensorflow-2.20.0-cp313-cp313-win_amd64.whl.metadata (4.6 kB)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (6.33.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (3.12.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (2.3.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from keras>=3.10.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from keras>=3.10.0->tensorflow) (0.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.10)
# Requirement already satisfied: pillow in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (12.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\paraj\appdata\local\programs\python\python313\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Using cached tensorflow-2.20.0-cp313-cp313-win_amd64.whl (332.0 MB)
# Installing collected packages: tensorflow

# %%
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import tensorflow as tf
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\__init__.py:40
#      37 _os.environ.setdefault("ENABLE_RUNTIME_UPTIME_TELEMETRY", "1")
#      39 # Do not remove this line; See https://github.com/tensorflow/tensorflow/issues/42596
# ---> 40 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow  # pylint: disable=unused-import
#      41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import KerasLazyLoader as _KerasLazyLoader
#
# ModuleNotFoundError: No module named 'tensorflow.python'

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 import tensorflow as tf
#       3 from tensorflow.keras.models import Sequential
#       4 from tensorflow.keras.layers import Dense, Flatten
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\__init__.py:40
#      37 _os.environ.setdefault("ENABLE_RUNTIME_UPTIME_TELEMETRY", "1")
#      39 # Do not remove this line; See https://github.com/tensorflow/tensorflow/issues/42596
# ---> 40 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow  # pylint: disable=unused-import
#      41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import KerasLazyLoader as _KerasLazyLoader
#
# ModuleNotFoundError: No module named 'tensorflow.python'

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Normalize the pixel values to range [0,1]
x_train = x_train / 255.0
x_test = x_test / 255.0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 (x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
#       3 # Normalize the pixel values to range [0,1]
#       4 x_train = x_train / 255.0
#
# NameError: name 'tf' is not defined

# %%
model = Sequential([
    Flatten(input_shape=(28, 28)),          # Flatten 28x28 image to 784 vector
    Dense(128, activation='relu'),          # Hidden layer with 128 neurons
    Dense(10, activation='softmax')         # Output layer with 10 classes
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model = Sequential([
#       2     Flatten(input_shape=(28, 28)),          # Flatten 28x28 image to 784 vector
#       3     Dense(128, activation='relu'),          # Hidden layer with 128 neurons
#       4     Dense(10, activation='softmax')         # Output layer with 10 classes
#       5 ])
#
# NameError: name 'Sequential' is not defined

# %%
# --- d. Compile the Model (using SGD optimizer) ---
optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)
model.compile(optimizer=optimizer,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# --- e. Train the Model ---
history = model.fit(x_train, y_train, epochs=10,
                    validation_data=(x_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # --- d. Compile the Model (using SGD optimizer) ---
# ----> 2 optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)
#       3 model.compile(optimizer=optimizer,
#       4               loss='sparse_categorical_crossentropy',
#       5               metrics=['accuracy'])
#       7 # --- e. Train the Model ---
#
# NameError: name 'tf' is not defined

# %%
# --- f. Evaluate the Network ---
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print(f'\nTest Accuracy: {test_acc:.4f}')

# --- g. Plot Training and Validation Loss and Accuracy ---
plt.figure(figsize=(12,5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # --- f. Evaluate the Network ---
# ----> 2 test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
#       3 print(f'\nTest Accuracy: {test_acc:.4f}')
#       5 # --- g. Plot Training and Validation Loss and Accuracy ---
#
# NameError: name 'model' is not defined

# %%
# Plot Loss
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Plot Loss
# ----> 2 plt.subplot(1,2,1)
#       3 plt.plot(history.history['loss'], label='Training Loss')
#       4 plt.plot(history.history['val_loss'], label='Validation Loss')
#
# NameError: name 'plt' is not defined
